# %%
import sys
import os

sys.path.append(os.path.abspath('src'))

# %%
import torch
import torchvision.models
import hiddenlayer as hl
from src import Model as model
from src.Model import bodypose_model, handpose_model

# %%
bodymodel = bodypose_model()
hl.build_graph(bodymodel, torch.zeros([1, 3, 368, 368]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4152\1733402690.py in <module>
#       1 bodymodel = bodypose_model()
# ----> 2 hl.build_graph(bodymodel, torch.zeros([1, 3, 368, 368]))
#
# F:\anaconda3\envs\badoupytorch\lib\site-packages\hiddenlayer\graph.py in build_graph(model, args, input_names, transforms, framework_transforms)
#     141         from .pytorch_builder import import_graph, FRAMEWORK_TRANSFORMS
#     142         assert args is not None, "Argument args must be provided for Pytorch models."
# --> 143         import_graph(g, model, args)
#     144     elif framework == "tensorflow":
#     145         from .tf_builder import import_graph, FRAMEWORK_TRANSFORMS
#
# F:\anaconda3\envs\badoupytorch\lib\site-packages\hiddenlayer\pytorch_builder.py in import_graph(hl_graph, model, args, input_names, verbose)
#      69     # Run the Pytorch graph to get a trace and generate a graph from it
#      70     trace, out = torch.jit._get_trace_graph(model, args)
# ---> 71     torch_graph = torch.onnx._optimize_trace(trace, torch.onnx.OperatorExportTypes.ONNX)
#      72
#      73     # Dump list of nodes (DEBUG only)
#
# F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\onnx\__init__.py in _optimize_trace(graph, operator_export_type)
#     392     from torch.onnx import utils
#     393
# --> 394     return utils._optimize_graph(graph, operator_export_type)
#     395
#     396
#
# F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\onnx\utils.py in _optimize_graph(graph, operator_export_type, _disable_torch_constant_prop, fixed_batch_size, params_dict, dynamic_axes, input_names, module)
#     276     # Unpack quantized weights for conv and linear ops and insert into graph.
#     277     _C._jit_pass_onnx_unpack_quantized_weights(
# --> 278         graph, params_dict, symbolic_helper.is_caffe2_aten_fallback()
#     279     )
#     280     if symbolic_helper.is_caffe2_aten_fallback():
#
# TypeError: _jit_pass_onnx_unpack_quantized_weights(): incompatible function arguments. The following argument types are supported:
#     1. (arg0: torch::jit::Graph, arg1: Dict[str, IValue], arg2: bool) -> Dict[str, IValue]
#
# Invoked with: graph(%input.1 : Float(1, 3, 368, 368, strides=[406272, 135424, 368, 1], requires_grad=0, device=cpu),
#       %1 : Float(64, 3, 3, 3, strides=[27, 9, 3, 1], requires_grad=1, device=cpu),
#       %2 : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %3 : Float(64, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cpu),
#       %4 : Float(64, strides=[1], requires_grad=1, device=cpu),
#       %5 : Float(128, 64, 3, 3, strides=[576, 9, 3, 1], requires_grad=1, device=cpu),
#       %6 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %7 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %8 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %9 : Float(256, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %10 : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %11 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %12 : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %13 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %14 : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %15 : Float(256, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %16 : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %17 : Float(512, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %18 : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %19 : Float(512, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=1, device=cpu),
#       %20 : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %21 : Float(256, 512, 3, 3, strides=[4608, 9, 3, 1], requires_grad=1, device=cpu),
#       %22 : Float(256, strides=[1], requires_grad=1, device=cpu),
#       %23 : Float(128, 256, 3, 3, strides=[2304, 9, 3, 1], requires_grad=1, device=cpu),
#       %24 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %25 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %26 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %27 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %28 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %29 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %30 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %31 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %32 : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %33 : Float(38, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %34 : Float(38, strides=[1], requires_grad=1, device=cpu),
#       %35 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %36 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %37 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %38 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %39 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %40 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %41 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %42 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %43 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %44 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %45 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %46 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %47 : Float(38, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %48 : Float(38, strides=[1], requires_grad=1, device=cpu),
#       %49 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %50 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %51 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %52 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %53 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %54 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %55 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %56 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %57 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %58 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %59 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %60 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %61 : Float(38, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %62 : Float(38, strides=[1], requires_grad=1, device=cpu),
#       %63 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %64 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %65 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %66 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %67 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %68 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %69 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %70 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %71 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %72 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %73 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %74 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %75 : Float(38, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %76 : Float(38, strides=[1], requires_grad=1, device=cpu),
#       %77 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %78 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %79 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %80 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %81 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %82 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %83 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %84 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %85 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %86 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %87 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %88 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %89 : Float(38, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %90 : Float(38, strides=[1], requires_grad=1, device=cpu),
#       %91 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %92 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %93 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %94 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %95 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %96 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %97 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %98 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %99 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %100 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %101 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %102 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %103 : Float(38, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %104 : Float(38, strides=[1], requires_grad=1, device=cpu),
#       %105 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %106 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %107 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %108 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %109 : Float(128, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cpu),
#       %110 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %111 : Float(512, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %112 : Float(512, strides=[1], requires_grad=1, device=cpu),
#       %113 : Float(19, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cpu),
#       %114 : Float(19, strides=[1], requires_grad=1, device=cpu),
#       %115 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %116 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %117 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %118 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %119 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %120 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %121 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %122 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %123 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %124 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %125 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %126 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %127 : Float(19, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %128 : Float(19, strides=[1], requires_grad=1, device=cpu),
#       %129 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %130 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %131 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %132 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %133 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %134 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %135 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %136 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %137 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %138 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %139 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %140 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %141 : Float(19, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %142 : Float(19, strides=[1], requires_grad=1, device=cpu),
#       %143 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %144 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %145 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %146 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %147 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %148 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %149 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %150 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %151 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %152 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %153 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %154 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %155 : Float(19, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %156 : Float(19, strides=[1], requires_grad=1, device=cpu),
#       %157 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %158 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %159 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %160 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %161 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %162 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %163 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %164 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %165 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %166 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %167 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %168 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %169 : Float(19, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %170 : Float(19, strides=[1], requires_grad=1, device=cpu),
#       %171 : Float(128, 185, 7, 7, strides=[9065, 49, 7, 1], requires_grad=1, device=cpu),
#       %172 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %173 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %174 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %175 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %176 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %177 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %178 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %179 : Float(128, 128, 7, 7, strides=[6272, 49, 7, 1], requires_grad=1, device=cpu),
#       %180 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %181 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %182 : Float(128, strides=[1], requires_grad=1, device=cpu),
#       %183 : Float(19, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cpu),
#       %184 : Float(19, strides=[1], requires_grad=1, device=cpu)):
#   %2442 : int[] = prim::Constant[value=[1, 1]]()
#   %2443 : int[] = prim::Constant[value=[1, 1]]()
#   %2444 : int[] = prim::Constant[value=[1, 1]]()
#   %564 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2445 : int[] = prim::Constant[value=[0, 0]]()
#   %568 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %569 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %570 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %571 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %572 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.3 : Float(1, 64, 368, 368, strides=[8667136, 135424, 368, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.1, %1, %2, %2442, %2443, %2444, %564, %2445, %568, %569, %570, %571, %572) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2822 : Float(1, 64, 368, 368, strides=[8667136, 135424, 368, 1], requires_grad=1, device=cpu) = aten::relu(%input.3) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2446 : int[] = prim::Constant[value=[1, 1]]()
#   %2447 : int[] = prim::Constant[value=[1, 1]]()
#   %2448 : int[] = prim::Constant[value=[1, 1]]()
#   %584 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2449 : int[] = prim::Constant[value=[0, 0]]()
#   %588 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %589 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %590 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %591 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %592 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.7 : Float(1, 64, 368, 368, strides=[8667136, 135424, 368, 1], requires_grad=0, device=cpu) = aten::_convolution(%2822, %3, %4, %2446, %2447, %2448, %584, %2449, %588, %589, %590, %591, %592) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2823 : Float(1, 64, 368, 368, strides=[8667136, 135424, 368, 1], requires_grad=1, device=cpu) = aten::relu(%input.7) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2450 : int[] = prim::Constant[value=[2, 2]]()
#   %2451 : int[] = prim::Constant[value=[2, 2]]()
#   %2452 : int[] = prim::Constant[value=[0, 0]]()
#   %2453 : int[] = prim::Constant[value=[1, 1]]()
#   %607 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:782:0
#   %input.9 : Float(1, 64, 184, 184, strides=[2166784, 33856, 184, 1], requires_grad=1, device=cpu) = aten::max_pool2d(%2823, %2450, %2451, %2452, %2453, %607) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:782:0
#   %2454 : int[] = prim::Constant[value=[1, 1]]()
#   %2455 : int[] = prim::Constant[value=[1, 1]]()
#   %2456 : int[] = prim::Constant[value=[1, 1]]()
#   %618 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2457 : int[] = prim::Constant[value=[0, 0]]()
#   %622 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %623 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %624 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %625 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %626 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.11 : Float(1, 128, 184, 184, strides=[4333568, 33856, 184, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.9, %5, %6, %2454, %2455, %2456, %618, %2457, %622, %623, %624, %625, %626) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2824 : Float(1, 128, 184, 184, strides=[4333568, 33856, 184, 1], requires_grad=1, device=cpu) = aten::relu(%input.11) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2458 : int[] = prim::Constant[value=[1, 1]]()
#   %2459 : int[] = prim::Constant[value=[1, 1]]()
#   %2460 : int[] = prim::Constant[value=[1, 1]]()
#   %638 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2461 : int[] = prim::Constant[value=[0, 0]]()
#   %642 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %643 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %644 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %645 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %646 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.15 : Float(1, 128, 184, 184, strides=[4333568, 33856, 184, 1], requires_grad=0, device=cpu) = aten::_convolution(%2824, %7, %8, %2458, %2459, %2460, %638, %2461, %642, %643, %644, %645, %646) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2825 : Float(1, 128, 184, 184, strides=[4333568, 33856, 184, 1], requires_grad=1, device=cpu) = aten::relu(%input.15) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2462 : int[] = prim::Constant[value=[2, 2]]()
#   %2463 : int[] = prim::Constant[value=[2, 2]]()
#   %2464 : int[] = prim::Constant[value=[0, 0]]()
#   %2465 : int[] = prim::Constant[value=[1, 1]]()
#   %661 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:782:0
#   %input.17 : Float(1, 128, 92, 92, strides=[1083392, 8464, 92, 1], requires_grad=1, device=cpu) = aten::max_pool2d(%2825, %2462, %2463, %2464, %2465, %661) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:782:0
#   %2466 : int[] = prim::Constant[value=[1, 1]]()
#   %2467 : int[] = prim::Constant[value=[1, 1]]()
#   %2468 : int[] = prim::Constant[value=[1, 1]]()
#   %672 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2469 : int[] = prim::Constant[value=[0, 0]]()
#   %676 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %677 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %678 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %679 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %680 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.19 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.17, %9, %10, %2466, %2467, %2468, %672, %2469, %676, %677, %678, %679, %680) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2826 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=1, device=cpu) = aten::relu(%input.19) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2470 : int[] = prim::Constant[value=[1, 1]]()
#   %2471 : int[] = prim::Constant[value=[1, 1]]()
#   %2472 : int[] = prim::Constant[value=[1, 1]]()
#   %692 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2473 : int[] = prim::Constant[value=[0, 0]]()
#   %696 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %697 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %698 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %699 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %700 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.23 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=0, device=cpu) = aten::_convolution(%2826, %11, %12, %2470, %2471, %2472, %692, %2473, %696, %697, %698, %699, %700) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2827 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=1, device=cpu) = aten::relu(%input.23) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2474 : int[] = prim::Constant[value=[1, 1]]()
#   %2475 : int[] = prim::Constant[value=[1, 1]]()
#   %2476 : int[] = prim::Constant[value=[1, 1]]()
#   %712 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2477 : int[] = prim::Constant[value=[0, 0]]()
#   %716 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %717 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %718 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %719 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %720 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.27 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=0, device=cpu) = aten::_convolution(%2827, %13, %14, %2474, %2475, %2476, %712, %2477, %716, %717, %718, %719, %720) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2828 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=1, device=cpu) = aten::relu(%input.27) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2478 : int[] = prim::Constant[value=[1, 1]]()
#   %2479 : int[] = prim::Constant[value=[1, 1]]()
#   %2480 : int[] = prim::Constant[value=[1, 1]]()
#   %732 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2481 : int[] = prim::Constant[value=[0, 0]]()
#   %736 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %737 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %738 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %739 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %740 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.31 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=0, device=cpu) = aten::_convolution(%2828, %15, %16, %2478, %2479, %2480, %732, %2481, %736, %737, %738, %739, %740) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2829 : Float(1, 256, 92, 92, strides=[2166784, 8464, 92, 1], requires_grad=1, device=cpu) = aten::relu(%input.31) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2482 : int[] = prim::Constant[value=[2, 2]]()
#   %2483 : int[] = prim::Constant[value=[2, 2]]()
#   %2484 : int[] = prim::Constant[value=[0, 0]]()
#   %2485 : int[] = prim::Constant[value=[1, 1]]()
#   %755 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:782:0
#   %input.33 : Float(1, 256, 46, 46, strides=[541696, 2116, 46, 1], requires_grad=1, device=cpu) = aten::max_pool2d(%2829, %2482, %2483, %2484, %2485, %755) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:782:0
#   %2486 : int[] = prim::Constant[value=[1, 1]]()
#   %2487 : int[] = prim::Constant[value=[1, 1]]()
#   %2488 : int[] = prim::Constant[value=[1, 1]]()
#   %766 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2489 : int[] = prim::Constant[value=[0, 0]]()
#   %770 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %771 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %772 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %773 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %774 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.35 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.33, %17, %18, %2486, %2487, %2488, %766, %2489, %770, %771, %772, %773, %774) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2830 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.35) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2490 : int[] = prim::Constant[value=[1, 1]]()
#   %2491 : int[] = prim::Constant[value=[1, 1]]()
#   %2492 : int[] = prim::Constant[value=[1, 1]]()
#   %786 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2493 : int[] = prim::Constant[value=[0, 0]]()
#   %790 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %791 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %792 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %793 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %794 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.39 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2830, %19, %20, %2490, %2491, %2492, %786, %2493, %790, %791, %792, %793, %794) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2831 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.39) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2494 : int[] = prim::Constant[value=[1, 1]]()
#   %2495 : int[] = prim::Constant[value=[1, 1]]()
#   %2496 : int[] = prim::Constant[value=[1, 1]]()
#   %806 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2497 : int[] = prim::Constant[value=[0, 0]]()
#   %810 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %811 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %812 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %813 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %814 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.43 : Float(1, 256, 46, 46, strides=[541696, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2831, %21, %22, %2494, %2495, %2496, %806, %2497, %810, %811, %812, %813, %814) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2832 : Float(1, 256, 46, 46, strides=[541696, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.43) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2498 : int[] = prim::Constant[value=[1, 1]]()
#   %2499 : int[] = prim::Constant[value=[1, 1]]()
#   %2500 : int[] = prim::Constant[value=[1, 1]]()
#   %826 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2501 : int[] = prim::Constant[value=[0, 0]]()
#   %830 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %831 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %832 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %833 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %834 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.47 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2832, %23, %24, %2498, %2499, %2500, %826, %2501, %830, %831, %832, %833, %834) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2833 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.47) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2502 : int[] = prim::Constant[value=[1, 1]]()
#   %2503 : int[] = prim::Constant[value=[1, 1]]()
#   %2504 : int[] = prim::Constant[value=[1, 1]]()
#   %846 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2505 : int[] = prim::Constant[value=[0, 0]]()
#   %850 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %851 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %852 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %853 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %854 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.51 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2833, %25, %26, %2502, %2503, %2504, %846, %2505, %850, %851, %852, %853, %854) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2834 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.51) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2506 : int[] = prim::Constant[value=[1, 1]]()
#   %2507 : int[] = prim::Constant[value=[1, 1]]()
#   %2508 : int[] = prim::Constant[value=[1, 1]]()
#   %866 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2509 : int[] = prim::Constant[value=[0, 0]]()
#   %870 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %871 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %872 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %873 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %874 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.55 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2834, %27, %28, %2506, %2507, %2508, %866, %2509, %870, %871, %872, %873, %874) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2835 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.55) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2510 : int[] = prim::Constant[value=[1, 1]]()
#   %2511 : int[] = prim::Constant[value=[1, 1]]()
#   %2512 : int[] = prim::Constant[value=[1, 1]]()
#   %886 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2513 : int[] = prim::Constant[value=[0, 0]]()
#   %890 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %891 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %892 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %893 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %894 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.59 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2835, %29, %30, %2510, %2511, %2512, %886, %2513, %890, %891, %892, %893, %894) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2836 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.59) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2514 : int[] = prim::Constant[value=[1, 1]]()
#   %2515 : int[] = prim::Constant[value=[0, 0]]()
#   %2516 : int[] = prim::Constant[value=[1, 1]]()
#   %906 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2517 : int[] = prim::Constant[value=[0, 0]]()
#   %910 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %911 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %912 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %913 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %914 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.63 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2836, %31, %32, %2514, %2515, %2516, %906, %2517, %910, %911, %912, %913, %914) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2837 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.63) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2518 : int[] = prim::Constant[value=[1, 1]]()
#   %2519 : int[] = prim::Constant[value=[0, 0]]()
#   %2520 : int[] = prim::Constant[value=[1, 1]]()
#   %926 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2521 : int[] = prim::Constant[value=[0, 0]]()
#   %930 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %931 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %932 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %933 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %934 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %935 : Float(1, 38, 46, 46, strides=[80408, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2837, %33, %34, %2518, %2519, %2520, %926, %2521, %930, %931, %932, %933, %934) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2522 : int[] = prim::Constant[value=[1, 1]]()
#   %2523 : int[] = prim::Constant[value=[1, 1]]()
#   %2524 : int[] = prim::Constant[value=[1, 1]]()
#   %945 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2525 : int[] = prim::Constant[value=[0, 0]]()
#   %949 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %950 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %951 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %952 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %953 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.67 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2833, %105, %106, %2522, %2523, %2524, %945, %2525, %949, %950, %951, %952, %953) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2838 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.67) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2526 : int[] = prim::Constant[value=[1, 1]]()
#   %2527 : int[] = prim::Constant[value=[1, 1]]()
#   %2528 : int[] = prim::Constant[value=[1, 1]]()
#   %965 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2529 : int[] = prim::Constant[value=[0, 0]]()
#   %969 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %970 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %971 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %972 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %973 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.71 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2838, %107, %108, %2526, %2527, %2528, %965, %2529, %969, %970, %971, %972, %973) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2839 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.71) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2530 : int[] = prim::Constant[value=[1, 1]]()
#   %2531 : int[] = prim::Constant[value=[1, 1]]()
#   %2532 : int[] = prim::Constant[value=[1, 1]]()
#   %985 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2533 : int[] = prim::Constant[value=[0, 0]]()
#   %989 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %990 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %991 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %992 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %993 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.75 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2839, %109, %110, %2530, %2531, %2532, %985, %2533, %989, %990, %991, %992, %993) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2840 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.75) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2534 : int[] = prim::Constant[value=[1, 1]]()
#   %2535 : int[] = prim::Constant[value=[0, 0]]()
#   %2536 : int[] = prim::Constant[value=[1, 1]]()
#   %1005 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2537 : int[] = prim::Constant[value=[0, 0]]()
#   %1009 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %1010 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %1011 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %1012 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %1013 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.79 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2840, %111, %112, %2534, %2535, %2536, %1005, %2537, %1009, %1010, %1011, %1012, %1013) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2841 : Float(1, 512, 46, 46, strides=[1083392, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.79) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2538 : int[] = prim::Constant[value=[1, 1]]()
# ...
#   %2892 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.293) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2778 : int[] = prim::Constant[value=[1, 1]]()
#   %2779 : int[] = prim::Constant[value=[3, 3]]()
#   %2780 : int[] = prim::Constant[value=[1, 1]]()
#   %2231 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2781 : int[] = prim::Constant[value=[0, 0]]()
#   %2235 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2236 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2237 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2238 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2239 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.297 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2892, %97, %98, %2778, %2779, %2780, %2231, %2781, %2235, %2236, %2237, %2238, %2239) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2893 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.297) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2782 : int[] = prim::Constant[value=[1, 1]]()
#   %2783 : int[] = prim::Constant[value=[3, 3]]()
#   %2784 : int[] = prim::Constant[value=[1, 1]]()
#   %2251 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2785 : int[] = prim::Constant[value=[0, 0]]()
#   %2255 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2256 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2257 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2258 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2259 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.301 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2893, %99, %100, %2782, %2783, %2784, %2251, %2785, %2255, %2256, %2257, %2258, %2259) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2894 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.301) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2786 : int[] = prim::Constant[value=[1, 1]]()
#   %2787 : int[] = prim::Constant[value=[0, 0]]()
#   %2788 : int[] = prim::Constant[value=[1, 1]]()
#   %2271 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2789 : int[] = prim::Constant[value=[0, 0]]()
#   %2275 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2276 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2277 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2278 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2279 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.305 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2894, %101, %102, %2786, %2787, %2788, %2271, %2789, %2275, %2276, %2277, %2278, %2279) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2895 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.305) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2790 : int[] = prim::Constant[value=[1, 1]]()
#   %2791 : int[] = prim::Constant[value=[0, 0]]()
#   %2792 : int[] = prim::Constant[value=[1, 1]]()
#   %2291 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2793 : int[] = prim::Constant[value=[0, 0]]()
#   %2295 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2296 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2297 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2298 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2299 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2300 : Float(1, 38, 46, 46, strides=[80408, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2895, %103, %104, %2790, %2791, %2792, %2291, %2793, %2295, %2296, %2297, %2298, %2299) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2794 : int[] = prim::Constant[value=[1, 1]]()
#   %2795 : int[] = prim::Constant[value=[3, 3]]()
#   %2796 : int[] = prim::Constant[value=[1, 1]]()
#   %2310 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2797 : int[] = prim::Constant[value=[0, 0]]()
#   %2314 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2315 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2316 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2317 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2318 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.309 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%input.283, %171, %172, %2794, %2795, %2796, %2310, %2797, %2314, %2315, %2316, %2317, %2318) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2896 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.309) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2798 : int[] = prim::Constant[value=[1, 1]]()
#   %2799 : int[] = prim::Constant[value=[3, 3]]()
#   %2800 : int[] = prim::Constant[value=[1, 1]]()
#   %2330 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2801 : int[] = prim::Constant[value=[0, 0]]()
#   %2334 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2335 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2336 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2337 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2338 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.313 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2896, %173, %174, %2798, %2799, %2800, %2330, %2801, %2334, %2335, %2336, %2337, %2338) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2897 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.313) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2802 : int[] = prim::Constant[value=[1, 1]]()
#   %2803 : int[] = prim::Constant[value=[3, 3]]()
#   %2804 : int[] = prim::Constant[value=[1, 1]]()
#   %2350 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2805 : int[] = prim::Constant[value=[0, 0]]()
#   %2354 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2355 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2356 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2357 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2358 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.317 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2897, %175, %176, %2802, %2803, %2804, %2350, %2805, %2354, %2355, %2356, %2357, %2358) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2898 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.317) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2806 : int[] = prim::Constant[value=[1, 1]]()
#   %2807 : int[] = prim::Constant[value=[3, 3]]()
#   %2808 : int[] = prim::Constant[value=[1, 1]]()
#   %2370 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2809 : int[] = prim::Constant[value=[0, 0]]()
#   %2374 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2375 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2376 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2377 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2378 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.321 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2898, %177, %178, %2806, %2807, %2808, %2370, %2809, %2374, %2375, %2376, %2377, %2378) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2899 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.321) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2810 : int[] = prim::Constant[value=[1, 1]]()
#   %2811 : int[] = prim::Constant[value=[3, 3]]()
#   %2812 : int[] = prim::Constant[value=[1, 1]]()
#   %2390 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2813 : int[] = prim::Constant[value=[0, 0]]()
#   %2394 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2395 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2396 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2397 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2398 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.325 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2899, %179, %180, %2810, %2811, %2812, %2390, %2813, %2394, %2395, %2396, %2397, %2398) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2900 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.325) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2814 : int[] = prim::Constant[value=[1, 1]]()
#   %2815 : int[] = prim::Constant[value=[0, 0]]()
#   %2816 : int[] = prim::Constant[value=[1, 1]]()
#   %2410 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2817 : int[] = prim::Constant[value=[0, 0]]()
#   %2414 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2415 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2416 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2417 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2418 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input.329 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2900, %181, %182, %2814, %2815, %2816, %2410, %2817, %2414, %2415, %2416, %2417, %2418) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2901 : Float(1, 128, 46, 46, strides=[270848, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input.329) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   %2818 : int[] = prim::Constant[value=[1, 1]]()
#   %2819 : int[] = prim::Constant[value=[0, 0]]()
#   %2820 : int[] = prim::Constant[value=[1, 1]]()
#   %2430 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2821 : int[] = prim::Constant[value=[0, 0]]()
#   %2434 : int = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2435 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2436 : bool = prim::Constant[value=0]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2437 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2438 : bool = prim::Constant[value=1]() # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %input : Float(1, 19, 46, 46, strides=[40204, 2116, 46, 1], requires_grad=0, device=cpu) = aten::_convolution(%2901, %183, %184, %2818, %2819, %2820, %2430, %2821, %2434, %2435, %2436, %2437, %2438) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\modules\conv.py:454:0
#   %2902 : Float(1, 19, 46, 46, strides=[40204, 2116, 46, 1], requires_grad=1, device=cpu) = aten::relu(%input) # F:\anaconda3\envs\badoupytorch\lib\site-packages\torch\nn\functional.py:1455:0
#   return (%2300, %2902)
# , None, False

# %%
handmodel = handpose_model()
hl.build_graph(handmodel, torch.zeros([1, 3, 368, 368]))
